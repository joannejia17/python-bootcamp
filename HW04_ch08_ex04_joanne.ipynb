# %%
# The following functions are all intended to check whether a string contains
# any lowercase letters, but at least some of them are wrong. For each
# function, describe (is the docstring) what the function actually does.
# You can assume that the parameter is a string.

# Do not merely paste the output as a counterexample into the documentation
# string, explain what is wrong.


###############################################################################
# Body


def any_lowercase1(s):
    """This one checks if the first letter is in lowercase and returns
    that result as the final one for the entire string. 
    """
    for c in s:
        if c.islower():
            return True
        else:
            return False


def any_lowercase2(s):
    """string 'c' is decidedly lowercase, so the answer will always be 
    True for this function.
    """
    for c in s:
        if 'c'.islower():
            return 'True'
        else:
            return 'False'


def any_lowercase3(s):
    """Because there is only one variable that holds the boolean for all the 
    letters in the string,and it wasn't printed out or returned every time, 
    the flag variable will only show the boolean value of the very last 
    letter. 
    """
    for c in s:
        flag = c.islower()
    return flag


def any_lowercase4(s):
    """This is correct.
    """
    flag = False
    for c in s:
        flag = flag or c.islower()
    return flag


def any_lowercase5(s):
    """This function returns False if any of the letters is 
    uppercase, which is not what the prompt asks for.
    """
    for c in s:
        if not c.islower():
            return False
    return True


###############################################################################
def main():

    # Remove print("Hello World!") and for each function above that is wrong,
    # call that function with a string for which the function returns
    # incorrectly.
    # ex.: any_lowercase_("thisstringmessesupthefunction")
    print("any_lowercase1 judges this string 'Thisstringmessesupthefunction' to be: ", any_lowercase1("Thisstringmessesupthefunction"))
    print("any_lowercase2 judges this string 'THISSTRINGMESSESUPTHEFUNCTION' to be: ",any_lowercase2("THISSTRINGMESSESUPTHEFUNCTION"))
    print("any_lowercase3 judges this string 'thisstringmessesupthefunctioN' to be: ",any_lowercase3("THISSTRINGMESSESUPTHEFUNCTION"))
    print("any_lowercase4 is correct.")
    print("any_lowercase5 judges this string 'Thisstringmessesupthefunction' to be: ",any_lowercase5("THISSTRINGMESSESUPTHEFUNCTION"))
if __name__ == '__main__':
    main()
# Out:
# any_lowercase1 judges this string 'Thisstringmessesupthefunction' to be:  False
# any_lowercase2 judges this string 'THISSTRINGMESSESUPTHEFUNCTION' to be:  True
# any_lowercase3 judges this string 'thisstringmessesupthefunctioN' to be:  False
# any_lowercase4 is correct.
# any_lowercase5 judges this string 'Thisstringmessesupthefunction' to be:  False
